# %%
import schemdraw
from schemdraw import flow

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=10, unit=.5)
    d += flow.Terminal().label('Start')
    d += flow.Arrow()
    d += flow.Process().label('Do something').drop('E')
    d += flow.Arrow().right()
    d += flow.Process().label('Do something\nelse')

# %% [markdown]
# # Superpixel test board
# ## Test Board
#
# ## Lidar Board
# + Deactivate ADC
# + Deactivate Test APD, SPAD, Ref APD, SPAD+TIA, and APD+TIA
